# %% [markdown]
# # Trouver le chemin de dash

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\sauss\miniconda3\envs\dash-env\python.exe

# %% [markdown]
# # Code de base pour app Dash

# %%
import dash
from dash import html, dcc, Input, Output, callback

app = dash.Dash()

app.layout = html.Div(children=[
    html.H2(children="Hello World!"),

    dcc.Input(id='input-1', value=" ", type='text'),
    html.Div(id='div-1',children=" ")
])

@callback(
    Output(component_id='dic-1', component_property='children'),
    [Input(component_id='input-1', component_property='value')]
)
def uptdate_div(input):
    return f'Texte introduit : {input}'

if __name__ == "__main__":
    app.run(debug=False, port=8050, jupyter_mode="external")
# Out:
# Dash app running on http://127.0.0.1:8050/

# %% [markdown]
# # Liste numérotée et puces

# %% [markdown]
# ## Astuce
#
# Pour taper du code HTML plus facilement (avec l'autocompression), on peut créer un nouveau fichier texte et changer en bas le style de texte de "Plain text" à "HTML"

# %% [markdown]
# <body>
#     <h3>Liste numerotée : </h3>
#     <ol>
#         <li>python</li>
#         <li>linux</li>
#         <li>pycharm</li>
#     </ol>
#     <h3>Puce classique:</h3>
#     <ul>
#         <li>python</li>
#         <li>linux</li>
#     </ul>
#     <a href="www.google.com">Google</a>
# </body>

# %% [markdown]
# # Images et Liens

# %% [markdown]
# <body>
#     <img src="assets/logo.jpeg" width="150" alt="Python Logo">
#     <br>
#     <br><a href="01_next_page.html">page suivante</a>
#     <br><a href="./02_table.html">Page table</a>
#     <br><a href="./03_input.html">Page formulaire</a>
#     <br><a href="./04_style.html">Page style CSS</a>
#     <br><a href="http://www.google.com">Google.com</a>
# </body>

# %% [markdown]
# # Tableau

# %% [markdown]
# <body>
#     <table border="1">
#         <thead>
#             <th>UserID</th>
#             <th>Rating</th>
#             <th>Age</th>
#         </thead>
#         <tr>
#             <td>001</td>
#             <td>4.5</td>
#             <td>25</td>
#         </tr>
#         <tr>
#             <td>002</td>
#             <td>4</td>
#             <td>23</td>
#         </tr>
#         <tr>
#             <td>003</td>
#             <td>5</td>
#             <td>21</td>
#         </tr>
#     </table>
# </body>

# %% [markdown]
# # Formulaire

# %% [markdown]
# <body>
#     <form>
#         <h3>Exemple de formualire</h3>
#         <input id="name" type="text" placeholder="Nom et prenom"> Nom et prenom <br> <br>
#         <input type="email" value="mail@exemple.com"> Email <br><br>
#         <input type="date"> Date de souscription <br><br>
#         <input type="checkbox" name="permis"> Avez vous le permis <br><br>
#         <input type="number"> Nombre de vélos <br><br>
#         <input type="password"> Mots de passe <br><br>
#     </form>
# </body>

# %% [markdown]
# # Style CSS

# %% [markdown]
# ## Astuce
# On peut faire comme pour le HTML, en créant un fichier spécifique. On pourra même défnir des styles que l'on peut réutiliser pas la suite

# %% [markdown]
# <body>
#     <h3 style="color: red ;font-size: 40px;font-family:'Times New Roman', Times, serif;">Liste numerotée : </h3>
#     <ol>
#         <li style="color: blue;font-size: 20px;">python</li>
#         <li>linux</li>
#         <li>pycharm</li>
#     </ol>
#     <h3>Puce classique:</h3>
#     <ul>
#         <li>python</li>
#         <li>linux</li>
#     </ul>
#     <a href="www.google.com">Google</a>
# </body>

# %% [markdown]
# # Exercice
# 1. Créer une cellule markdown
# 2. Ajoutez un formulaire demandant à l'utilisateur son nom, prénom, adesse e-mail et âge
# 3. Ajoutez une liste à puces dans laquelle vous pouvez énumérer trois de vos passe-temps péférés.
# 4. Créer un tableau de produits contenant trois produits pris aléatoirement avec les colonnes suivantes: Nom du produit, Prix, Qunatité.

# %% [markdown]
# <body>
#     <form ></form>
#         <input id="name" type="text" placeholder="Nom"> Nom <br> <br>
#         <input id="name" type="text" placeholder="Prenom"> Prenom <br> <br>
#         <input type="email" value="mail@exemple.com"> Email <br><br>
#         <input type="number"> Âge <br><br>
# </body>
#
# <body>
#     <h3>Liste numerotée : </h3>
#     <ol>
#         <li>Manger</li>
#         <li>Dormir</li>
#         <li>Boire</li>
#     </ol>
# </body>
#
# <body>
#     <table border="1">
#         <thead>
#             <th>Nom du produit</th>
#             <th>Prix</th>
#             <th>Quantité</th>
#         </thead>
#         <tr>
#             <td>Pomme</td>
#             <td>2.5</td>
#             <td>200</td>
#         </tr>
#         <tr>
#             <td>Poire</td>
#             <td>3</td>
#             <td>150</td>
#         </tr>
#         <tr>
#             <td>Prune</td>
#             <td>5</td>
#             <td>100</td>
#         </tr>
#     </table>
# </body>
