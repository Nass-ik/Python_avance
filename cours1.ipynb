# %% [markdown]
# pour copier sur git = git clone
# pour suivre les modif sur git = git add
# pour avoir une version = git commit
# envoyer les moodif = git push
# recevoir les modif = git pull

# %%
import dash

# %%
print("juste un test")
# Out:
# juste un test
